# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px

from textblob import Blobber
from textblob_fr import PatternTagger, PatternAnalyzer
tb = Blobber(pos_tagger=PatternTagger(), analyzer=PatternAnalyzer())

import re

import spacy
from spacy.lang.fr.stop_words import STOP_WORDS

import nltk ## traitement sur le texte
nltk.download('punkt') ## nltk tokenizer requiert punkt package
from nltk import word_tokenize ## fonction pour tockenizer
from nltk.corpus import stopwords ##  stopwords dans différentes langues
nltk.download('stopwords')## nltk corpus requiert punkt package
nltk.download('wordnet') ## nltk stem requiert punkt package
from nltk.stem import WordNetLemmatizer # Lemmatizer

from tqdm.auto import tqdm # for progress bar

from vaderSentiment_fr.vaderSentiment import SentimentIntensityAnalyzer
#from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

import time
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\theoj\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\theoj\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\theoj\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df = pd.read_csv("csv/scraped_reviews.csv", sep=";")
df.head()
# Out:
#     consumer_name  consumer_nb_review_writed  stars  \
# 0       Ghestin K                          1    5.0
# 1         Sylvain                          2    5.0
# 2          Helrat                          4    5.0
# 3  Laura Perrault                          1    5.0
# 4    HENRY KARINE                          2    5.0
#
#                              title_review  \
# 0                           Les meilleurs
# 1              Un large choix de produits
# 2                        Toujours parfait
# 3  Site aussi bon que d'habitude ou l'on…
# 4                                  Super!
#
#                                       content_review date_experience  \
# 0  Large catalogue, SAV a l’écoute et compréhensi...    15 mars 2021
# 1  Un large choix de produits, du Matos de qualit...    15 mars 2021
# 2  Toujours parfait. Depuis 4 ans, je commande to...    14 mars 2021
# 3  Site aussi bon que d'habitude ou l'on trouve p...     8 mars 2021
# 4  Présentation agréable, conseils rapides et ada...    11 mars 2021
#
#                    company                category
# 0  www.lepetitvapoteur.com  food_beverages_tobacco
# 1  www.lepetitvapoteur.com  food_beverages_tobacco
# 2  www.lepetitvapoteur.com  food_beverages_tobacco
# 3  www.lepetitvapoteur.com  food_beverages_tobacco
# 4  www.lepetitvapoteur.com  food_beverages_tobacco

# %% [markdown]
# # drop na comment

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141006 entries, 0 to 141005
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   consumer_name              141000 non-null  object
#  1   consumer_nb_review_writed  141006 non-null  int64
#  2   stars                      141000 non-null  float64
#  3   title_review               141000 non-null  object
#  4   content_review             125918 non-null  object
#  5   date_experience            29406 non-null   object
#  6   company                    141006 non-null  object
#  7   category                   141006 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 8.6+ MB

# %%
df = df[df["content_review"].notna()]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 125918 entries, 0 to 141005
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   consumer_name              125912 non-null  object
#  1   consumer_nb_review_writed  125918 non-null  int64
#  2   stars                      125918 non-null  float64
#  3   title_review               125918 non-null  object
#  4   content_review             125918 non-null  object
#  5   date_experience            25494 non-null   object
#  6   company                    125918 non-null  object
#  7   category                   125918 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 8.6+ MB

# %% [markdown]
# # join title and content

# %%
# df["review"] = df["title_review"] + " " + df["content_review"]
# df.head()

# %%
# df = df.drop(["consumer_name", "consumer_nb_review_writed", "date_experience", "company", "category"], axis=1)
# df.head()

# %%
df["review"] = df["content_review"]

# %% [markdown]
# # PREPROCESS

# %%
def clean_text(txt: str) -> str:
    """
    clean_text : remove "numbers, spec caracs, <br \>" in string
    
    params:
        txt -> string : string to clean
    return:
        txt -> string : cleaned string
    """

    # en regex "^" spécifie de ne garder que les carac spécifiés
    #print(re.sub(r"[A-Z|a-z| |']", r" ", txt))
    #txt = re.sub(r"[^A-Z|a-z]", r" ", txt)
    carac = chr(8217)
    txt = re.sub(r"['|,|.|" + carac + r"]", r" ", txt)
    txt = txt.lower()
    
    return txt

# %%
def remove_stop_words(txt: list) -> list:
    """
    remove_stop_words : remove useless words in string
    
    params:
        txt -> list : list of string to remove stop words
    return:
        txt -> string : list of string without stop words
    """

    txt = [x for x in txt if x not in stop_words]
    return txt

# %%
lemmatizer = WordNetLemmatizer()

def lemmatize(tokens: list) -> list:
    """
    Convert words from list to their common base forms
    Params
        tokens -> list : list of words to lemmatize
    Return
        lemmatized_tokens -> list: list of lemmatized words
    """
    
    for i in ["a", "v"]:
        tokens = list(map(lambda x: lemmatizer.lemmatize(x, i), tokens))
    
    return tokens

# %%
def preprocess(txt: str) -> list:
    """
    Cleans, Tokenize, lemmatize text and remove stop words
    Params:
        txt -> str: text to preprocess
    Return:
        txt -> str: preprocessed text
    """
    
    txt = clean_text(txt)
    
    txt = word_tokenize(txt)
    
    txt = remove_stop_words(txt)
    
    txt = lemmatize(txt)
    
    txt = " ".join(txt)
    
    return txt

# %%
print(stop_words)
# Out:
# {'j’', 'rendre', 'doivent', 'surtout', 'mille', 'peux', 'semblaient', 'se', 'serait', 'tres', 'neuvième', 'une', 'troisième', 'fais', 'ouvert', 'dedans', 'suivre', 'different', 'je', "l'", 'ouverts', 'delà', 'm’', 'etc', 'abord', "s'", 'étaient', 'malgre', 'parle', 'aucun', 'troisièmement', 'laquelle', 'moi', 'compris', 'façon', 'suivants', 'oust', 'quelconque', 'excepté', "n'", 'prealable', 'quel', 'egalement', 'autrement', 'seize', 'dans', 'douzième', "d'", 'lors', 'derriere', 'six', 'deja', 'quand', 'hou', 'eu', 'etais', 'enfin', 'etant', 'soi-même', 'un', 'cinquante', "t'", 'quanta', 'unes', 'moindres', 'celui-ci', 'tellement', 'soi', 'toutes', 'memes', 'meme', 'partant', 'assez', 'treize', 'trois', 'duquel', 'des', 'devra', 'en', 'dit', 'vers', 'celle-ci', 'sur', 'donc', 'qui', 'relativement', 'sans', 'auraient', 'été', 'onze', 'suffit', 'différente', 'revoici', 'tant', 'avons', 'suivant', 'diverse', 'nos', 'suffisant', 'restent', 'sait', 'dès', 'tente', 'toi', 'quelles', 'dix-sept', 'concernant', 'autres', 'souvent', 'maintenant', 'ouias', 'tu', 'onzième', 'lesquels', 'première', 'premièrement', 'sa', 'pense', 'tous', 'parmi', 'miens', 'ces', 'on', 'bat', 'quant', 'ai', 'seul', 'elles', 'pour', 'chez', 'apres', 'sien', 'tels', 'maint', 'relative', 'parlent', 'ah', 'que', 'hi', 'pourrait', 'chaque', 's’', 'retour', 'neanmoins', 'voilà', 'lès', 'avais', 'parfois', 'hep', 'uns', 'a', 'reste', 'certains', 'ta', 'parce', 'ouverte', 'avaient', 'eux-mêmes', 'possible', 'tend', 'car', 'deuxième', 'lui-meme', 'cette', 'exactement', 'c’', 'lesquelles', 'plusieurs', 'tenir', 'pres', 'leur', 'toute', 'différentes', 'hors', 'moi-meme', 'même', 'nul', 'egale', 'plutôt', 'lui', 'mais', 'tien', 'à', 'es', 'envers', 'mien', 'etre', 'puis', 'dix-neuf', 'du', 'parler', 'semble', 'etait', 'désormais', 'autre', 'cinquantaine', 'là', 'auquel', 'outre', 'soixante', 'ès', 'quelques', 'avec', 'sept', 'dits', 'desormais', 'hui', 'aupres', 'certaines', 'dixième', 'douze', 'encore', 'dire', 'semblable', 'près', 'sixième', 'revoilà', 'stop', 'qu’', 'notre', 'sienne', 'telle', 'ton', "quelqu'un", 'elle', 'dont', 'lui-même', 'quatrième', 'soit', 'hé', 'mienne', 'feront', 'suivantes', 'importe', 'egales', 'son', 'ne', 'devant', 'sinon', 'effet', 'derrière', 'telles', 'semblent', 'desquels', 'depuis', 'septième', 'sent', 'avait', 'l’', 'vous', 'o', 'possibles', 'quiconque', 'dehors', 'parseme', 'fait', 'moins', 'quant-à-soi', 'vas', 'basee', 'cet', 'deux', 'deuxièmement', 'ce', 'juste', 'ore', 'personne', 'ci', 'as', 'ni', 'permet', 'va', 'me', 'cent', 'quoi', 'au', 'sera', 'chacun', 'celle', 'vu', 'quatre', 'le', 'pu', 'quels', 'té', 'i', 'differents', 'seront', 'tout', "c'", 'ceci', 'certain', 'quelle', 'houp', 'hem', 'certes', 'la', 'celui-là', 'dessous', 'pouvait', 'ait', 'durant', 'différent', 'eux', 'jusqu', 'votre', 'auront', 'etaient', 'pas', 'cela', 'd’', 'debout', 'jusque', "m'", 't’', 'sauf', 'suit', 'attendu', 'mon', 'ceux', 'avant', 'quarante', 'directement', 'quoique', 'plus', 'aurait', "aujourd'hui", 'lequel', 'suis', 'na', 'leurs', 'restant', 'moi-même', 'longtemps', 'faisaient', 'quatorze', "qu'", 'pourrais', 'dix', 'mêmes', 'si', 'autrui', 'alors', 'aussi', 'laisser', 'être', 'premier', 'les', 'celles-ci', 'da', 'cependant', 'ça', 'cinq', 'ceux-là', 'desquelles', 'aie', 'divers', 'vais', 'ils', 'directe', 'specifique', 'comme', 'ayant', 'peu', 'precisement', 'combien', 'celle-là', 'tel', 'vos', 'ô', 'merci', 'siens', 'huitième', 'anterieur', 'n’', 'rend', 'était', 'specifiques', 'tienne', 'vôtres', 'puisque', 'ou', 'selon', 'dessus', 'differentes', 'elle-même', 'notamment', 'eh', 'allons', 'ont', 'trente', 'vôtre', 'sous', 'étant', "j'", 'ceux-ci', 'gens', 'où', 'lorsque', 'environ', 'mes', 'cinquième', 'quatre-vingt', 'aux', 'doit', 'auxquels', 'quinze', 'tenant', 'proche', 'sont', 'est', 'seule', 'par', 'tes', 'celui', 'tiens', 'aucune', 'tiennes', 'auxquelles', 'font', 'nous-mêmes', 'devers', 'via', 'anterieures', 'nôtre', 'entre',  ...

# %%
tqdm.pandas()

stop_words = set(STOP_WORDS)

df["preprocess_review"] = df["review"].progress_apply(preprocess)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=125918.0), HTML(value='')))

# %%
print(df["review"][0])
print(df["preprocess_review"][0])
# Out:
# Large catalogue, SAV a l’écoute et compréhensif, site facile d’utilisation avec de nombreux guides, livraison simple et rapide, nombreuses réductions et cadeaux.De loin le meilleur site de cigarette électronique sur le marché français.À quand une application?
# large catalogue sav l écoute compréhensif site facile d utilisation guide livraison simple rapide réductions cadeaux loin meilleur site cigarette électronique marché français application ?

# %% [markdown]
# # sentiment analyse

# %%
def sentiment_analyse(column):

    senti_list = []
    senti_nb = []
    senti_confidence = []
    
    for i in df[column]:
        vs = tb(i).sentiment
        senti_nb.append(vs[0])
        senti_confidence.append(vs[1])
        if (vs[0] > 0):
            senti_list.append(2)
        elif (vs[0] < 0):
            senti_list.append(0)
        else:
            senti_list.append(1) 

    df["sentiment"] = senti_list
    df["sentiment_nb"] = senti_nb
    df["sentiment_confidence"] = senti_confidence
    return df


#     senti_list = []
#     senti_confidence = []
#     SIA = SentimentIntensityAnalyzer()
    
#     for i in df[column]:
#         #score = SIA.polarity_scores_max(i)
#         score = SIA.polarity_scores(i)
#         if score["compound"] > 0.05:
#             senti_confidence.append(score["pos"])
#             senti_list.append(2)
#         elif score["compound"] >= -0.05 and score["compound"] <= 0.05:
#             senti_confidence.append(score["neu"])
#             senti_list.append(1)
#         else:
#             senti_confidence.append(score["neg"])
#             senti_list.append(0)
            
#     df["sentiment"] = senti_list
#     df["sentiment_confidence"] = senti_confidence
#     return df


#df = sentiment_analyse("review")
df = sentiment_analyse("preprocess_review")
df.head()
# Out:
#     consumer_name  consumer_nb_review_writed  stars  \
# 0       Ghestin K                          1    5.0
# 1         Sylvain                          2    5.0
# 2          Helrat                          4    5.0
# 3  Laura Perrault                          1    5.0
# 4    HENRY KARINE                          2    5.0
#
#                              title_review  \
# 0                           Les meilleurs
# 1              Un large choix de produits
# 2                        Toujours parfait
# 3  Site aussi bon que d'habitude ou l'on…
# 4                                  Super!
#
#                                       content_review date_experience  \
# 0  Large catalogue, SAV a l’écoute et compréhensi...    15 mars 2021
# 1  Un large choix de produits, du Matos de qualit...    15 mars 2021
# 2  Toujours parfait. Depuis 4 ans, je commande to...    14 mars 2021
# 3  Site aussi bon que d'habitude ou l'on trouve p...     8 mars 2021
# 4  Présentation agréable, conseils rapides et ada...    11 mars 2021
#
#                    company                category  \
# 0  www.lepetitvapoteur.com  food_beverages_tobacco
# 1  www.lepetitvapoteur.com  food_beverages_tobacco
# 2  www.lepetitvapoteur.com  food_beverages_tobacco
# 3  www.lepetitvapoteur.com  food_beverages_tobacco
# 4  www.lepetitvapoteur.com  food_beverages_tobacco
#
#                                               review  \
# 0  Large catalogue, SAV a l’écoute et compréhensi...
# 1  Un large choix de produits, du Matos de qualit...
# 2  Toujours parfait. Depuis 4 ans, je commande to...
# 3  Site aussi bon que d'habitude ou l'on trouve p...
# 4  Présentation agréable, conseils rapides et ada...
#
#                                    preprocess_review  sentiment  \
# 0  large catalogue sav l écoute compréhensif site...          2
# 1  large choix produits matos qualité livraison r...          2
# 2  parfait 4 ans commande matériel diy liquide e-...          2
# 3  site bon d habitude l trouve pleins petits con...          2
# 4  présentation agréable conseils rapides adaptés...          2
#
#    sentiment_confidence  sentiment_nb
# 0              0.266667      0.266667
# 1              0.200000      0.300000
# 2              0.533333      0.211667
# 3              0.350000      0.207500
# 4              0.400000      0.450000

# %%
print(df["sentiment"].value_counts())
print(df["stars"].value_counts())
# Out:
# 2    112696
# 1      7511
# 0      5711
# Name: sentiment, dtype: int64
# 5.0    108835
# 4.0     11983
# 3.0      2084
# 1.0      2070
# 2.0       946
# Name: stars, dtype: int64

# %%
df[df["sentiment"]==0]
# Out:
#                     consumer_name  consumer_nb_review_writed  stars  \
# 34                   Isabelle L-v                          1    5.0
# 132               Dominique Jouan                          5    5.0
# 168     Catherine Françoise Fragu                          1    5.0
# 237                        Client                          2    1.0
# 271                       Wilfrid                          1    2.0
# ...                           ...                        ...    ...
# 140775           Matthias Carrere                          1    5.0
# 140784                    GEORGES                          1    5.0
# 140825          Mr DONOVAN Rosati                          2    1.0
# 140874            CEDRIC veysauto                          1    4.0
# 140947               Rodolphe Das                          1    5.0
#
#                                     title_review  \
# 34       Client depuis 2 ans société et conseil…
# 132                                  Rien à dire
# 168                                       Nickel
# 237            Première expérience très mauvaise
# 271     Tout d'abord nous étions très satisfait…
# ...                                          ...
# 140775      Au top rien à dire meilleur site de…
# 140784          J'ai acheté 2 pièces pour un rzr
# 140825     Bonjour je ne suis pas satisfait car…
# 140874    Dommage que personne m est recontacte…
# 140947        Je recommande à 200% une équipe à…
#
#                                            content_review  date_experience  \
# 34      Client depuis 2 ans société et conseil au top ...  23 février 2021
# 132     Rien à dire, tout est parfait, sauf que je n'a...              NaN
# 168     Nickel Rapidité et qualité Équipe très réactiv...              NaN
# 237     Première expérience très très mauvaise...J'ai ...              NaN
# 271     Tout d'abord nous étions très satisfait de la ...   2 février 2021
# ...                                                   ...              ...
# 140775  Au top rien à dire meilleur site de vente de p...      2 mars 2021
# 140784  J'ai acheté 2 pièces pour un rzr; toit et pare...  28 février 2021
# 140825  Bonjour je ne suis pas satisfait car j'ai eu u...  22 février 2021
# 140874  Dommage que personne m est recontacte comme an...  11 février 2021
# 140947  Je recommande à 200% une équipe à l'écoute dès...              NaN
#
#                          company                 category  \
# 34       www.lepetitvapoteur.com   food_beverages_tobacco
# 132      www.lepetitvapoteur.com   food_beverages_tobacco
# 168      www.lepetitvapoteur.com   food_beverages_tobacco
# 237      www.lepetitvapoteur.com   food_beverages_tobacco
# 271     www.comptoirdesvignes.fr   food_beverages_tobacco
# ...                          ...                      ...
# 140775          www.tonnycat.com  vehicles_transportation
# 140784          www.tonnycat.com  vehicles_transportation
# 140825          www.tonnycat.com  vehicles_transportation
# 140874          www.tonnycat.com  vehicles_transportation
# 140947          www.tonnycat.com  vehicles_transportation
#
#                                                    review  \
# 34      Client depuis 2 ans société et conseil au top ...
# 132     Rien à dire, tout est parfait, sauf que je n'a...
# 168     Nickel Rapidité et qualité Équipe très réactiv...
# 237     Première expérience très très mauvaise...J'ai ...
# 271     Tout d'abord nous étions très satisfait de la ...
# ...                                                   ...
# 140775  Au top rien à dire meilleur site de vente de p...
# 140784  J'ai acheté 2 pièces pour un rzr; toit et pare...
# 140825  Bonjour je ne suis pas satisfait car j'ai eu u...
# 140874  Dommage que personne m est recontacte comme an...
# 140947  Je recommande à 200% une équipe à l'écoute dès...
#
#                                         preprocess_review  sentiment  \
# 34      client 2 ans société conseil top recommande ye...          0
# 132      rien parfait n reçu masque lpv croyais temps pis          0
# 168     nickel rapidité qualité équipe très réactive j...          0
# 237     expérience très très mauvaise j passé commande...          0
# 271     d étions très satisfait boutique y trouver reç...          0
# ...                                                   ...        ...
# 140775      top rien meilleur site vente pièces détachées          0
# 140784  j acheté 2 pièces rzr ; toit pare brise dernie...          0
# 140825  bonjour satisfait j erreurs commande coup j pe...          0
# 140874                       dommage m recontacte annoncé          0
# 140947  recommande 200 % équipe l écoute qu y problème...          0
#
#         sentiment_confidence  sentiment_nb
# 34                  0.125000     -0.040000
# 132                 0.800000     -0.400000
# 168                 0.262500     -0.042500
# 237                 0.271429     -0.258571
# 271                 0.422222     -0.087778
# ...                      ...           ...
# 140775              0.300000     -0.182500
# 140784              0.262500     -0.022500
# 140825              0.466667     -0.126302
# 140874              0.500000     -0.300000
# 140947              0.125000     -0.040000
#
# [5711 rows x 13 columns]

# %%
df_for_train = df[(df["sentiment_confidence"] > 0.8)]
#df[(df["sentiment_confidence"] > 0.7) & (df["stars"] == 1)]
display(df_for_train.head())

print(df_for_train["sentiment"].value_counts())
# Out:
#          consumer_name  consumer_nb_review_writed  stars  \
# 21    Sébastien GILLET                          1    5.0
# 22     christine lemle                          3    5.0
# 117  saint yves CECILE                          1    5.0
# 143           Patricia                          2    5.0
# 153             Jo. Nj                          2    5.0
#
#                            title_review  \
# 21     Toujours très content de ce site
# 22                           Super site
# 117                             Parfait
# 143  Super produits à tout les prix et…
# 153                    Très bon service
#
#                                         content_review  date_experience  \
# 21   Toujours très content de ce site, des produits...  26 février 2021
# 22                         Super site . Jamais déçue .  26 février 2021
# 117         Parfait, comme d'habitude 48h c'est génial              NaN
# 143  Super produits à tout les prix et surtout très...              NaN
# 153            Très bon service, jamais un seul soucis              NaN
#
#                      company                category  \
# 21   www.lepetitvapoteur.com  food_beverages_tobacco
# 22   www.lepetitvapoteur.com  food_beverages_tobacco
# 117  www.lepetitvapoteur.com  food_beverages_tobacco
# 143  www.lepetitvapoteur.com  food_beverages_tobacco
# 153  www.lepetitvapoteur.com  food_beverages_tobacco
#
#                                                 review  \
# 21   Toujours très content de ce site, des produits...
# 22                         Super site . Jamais déçue .
# 117         Parfait, comme d'habitude 48h c'est génial
# 143  Super produits à tout les prix et surtout très...
# 153            Très bon service, jamais un seul soucis
#
#                                      preprocess_review  sentiment  \
# 21   très content site produits proposés rapidité l...          2
# 22                             super site jamais déçue          2
# 117                    parfait d habitude 48h c génial          2
# 143  super produits prix très rapide niveaux livrai...          2
# 153                     très bon service jamais soucis          2
#
#      sentiment_confidence  sentiment_nb
# 21                   1.00          1.00
# 22                   0.95          0.60
# 117                  0.90          0.85
# 143                  0.85          0.70
# 153                  1.00          1.00
# 2    8869
# 0     200
# 1      18
# Name: sentiment, dtype: int64

# %%
df_for_train[df_for_train["sentiment"]==0]
# Out:
#             consumer_name  consumer_nb_review_writed  stars  \
# 1443          Denis LOUIS                          1    5.0
# 1919         Mazloum Nour                          2    5.0
# 3106          Marie Robin                          1    5.0
# 3231    Marie-Odile BAZIN                          1    1.0
# 3314           linda mine                          1    1.0
# ...                   ...                        ...    ...
# 136261     Lionel FLEURET                          3    4.0
# 137029         aubry tony                          1    5.0
# 138617     Marie Jo Basle                          2    5.0
# 139343              Oriol                          2    5.0
# 139502              Pedro                          1    5.0
#
#                                     title_review  \
# 1443            Très satisfait que la livraison…
# 1919                                  Incroyable
# 3106      Toujours très satisfaite des produits…
# 3231    Je suis un peu déçu.Je n'ai pas reçu ma…
# 3314          déçu de la composition du produit…
# ...                                          ...
# 136261                                   bonjour
# 137029                                     impec
# 138617                              Jamai déçue.
# 139343                                   Parfait
# 139502                Tres bonne relation client
#
#                                            content_review date_experience  \
# 1443    Très satisfait que la livraison corresponde ex...             NaN
# 1919    J’avais vraiment 0 mal de crâne en lendemain d...             NaN
# 3106    Toujours très satisfaite des produits et servi...             NaN
# 3231    Je suis un peu déçu.Je n'ai pas reçu ma comman...             NaN
# 3314    déçu de la composition du produit contrairemen...             NaN
# ...                                                   ...             ...
# 136261  bonjour les roulements commandés ont ete monte...    16 mars 2021
# 137029                            Rien à dire! impeccable     4 mars 2021
# 138617  Jamaisi déçue.Servcie, disponibilité, accueil ...             NaN
# 139343  Troisième expérience de location chez Ford et ...             NaN
# 139502  Entreprise trés réactive au besoin des clients...             NaN
#
#                          company                 category  \
# 1443     au-droit-de-bouchon.com   food_beverages_tobacco
# 1919                  alcoool.fr   food_beverages_tobacco
# 3106            www.oliquide.com   food_beverages_tobacco
# 3231           nutri-naturel.com   food_beverages_tobacco
# 3314           nutri-naturel.com   food_beverages_tobacco
# ...                          ...                      ...
# 136261      www.123roulement.com  vehicles_transportation
# 137029  www.lacameraembarquee.fr  vehicles_transportation
# 138617         izipark-nantes.fr  vehicles_transportation
# 139343           www.fordrent.fr  vehicles_transportation
# 139502                  homat.fr  vehicles_transportation
#
#                                                    review  \
# 1443    Très satisfait que la livraison corresponde ex...
# 1919    J’avais vraiment 0 mal de crâne en lendemain d...
# 3106    Toujours très satisfaite des produits et servi...
# 3231    Je suis un peu déçu.Je n'ai pas reçu ma comman...
# 3314    déçu de la composition du produit contrairemen...
# ...                                                   ...
# 136261  bonjour les roulements commandés ont ete monte...
# 137029                            Rien à dire! impeccable
# 138617  Jamaisi déçue.Servcie, disponibilité, accueil ...
# 139343  Troisième expérience de location chez Ford et ...
# 139502  Entreprise trés réactive au besoin des clients...
#
#                                         preprocess_review  sentiment  \
# 1443    très satisfait livraison corresponde commande ...          0
# 1919    j vraiment 0 mal crâne lendemain soirée faut t...          0
# 3106    très satisfaite produits service sav top réact...          0
# 3231    déçu n reçu commande devait arriver 29/12/2020...          0
# 3314          déçu composition produit contrairement j lu          0
# ...                                                   ...        ...
# 136261  bonjour roulements commandés ete monter rien c...          0
# 137029                                  rien ! impeccable          0
# 138617    jamaisi déçue servcie disponibilité accueil top          0
# 139343  expérience location ford déçu l accueil presta...          0
# 139502  entreprise trés réactive besoin clients : s aj...          0
#
#         sentiment_confidence  sentiment_nb
# 1443                1.000000     -0.200000
# 1919                1.000000     -1.000000
# 3106                1.000000     -0.125000
# 3231                1.000000     -1.000000
# 3314                1.000000     -1.000000
# ...                      ...           ...
# 136261              1.000000     -0.350000
# 137029              1.000000     -0.350000
# 138617              1.000000     -1.000000
# 139343              0.933333     -0.316667
# 139502              1.000000     -0.250000
#
# [200 rows x 13 columns]

# %%
df_for_train.to_csv("df_for_train.csv", sep=";", index=False)
