# %%
from scrap_company import *
from scrap_category import *

# %%
df_categories = pd.read_csv("csv/categories.csv")
df_categories.head()
print(df_categories["link"][0])
# Out:
# food_beverages_tobacco

# %%
dict_companies, dict_reviews = scrap_category("food_beverages_tobacco", max_companies=40, max_reviews=100)

df_companies = pd.DataFrame(data=dict_companies)
df_reviews = pd.DataFrame(data=dict_reviews)

display(df_companies)
display(df_reviews)
# Out:
# 9
# 5
# 9
# 5
# 9
# 5
# 9
# 5
# 9
# 5
# 9
# 5
# 9
# 5
# 9
# 5
# 9
# 5
# 9
# 5
#                     name        category_link               company_link  \
# 0  Château de l'Aumérade  agriculture_produce               aumerade.com
# 1             Potimarron  agriculture_produce             potimarron.com
# 2            Le Comptoir  agriculture_produce             lecomptoir.app
# 3        acemartmall.com  agriculture_produce            acemartmall.com
# 4          Cap Spiruline  agriculture_produce           capspiruline.com
# 5              Pourdebon  agriculture_produce              pourdebon.com
# 6  Château de La Rivière  agriculture_produce  chateau-de-la-riviere.com
# 7             HEMPLR CBD  agriculture_produce             premium-cbd.fr
# 8              Joli Thym  agriculture_produce               joli-thym.fr
# 9          Famillevacher  agriculture_produce           famillevacher.fr
#
#             type                                           location  \
# ...

# %%
dict_company, dict_reviews = scrap_company("cafesbelleville.com", max_reviews=100)

df_company = pd.DataFrame(data=dict_company, index=[0])
df_reviews = pd.DataFrame(data=dict_reviews)

display(df_company)
display(df_reviews)
# Out:
#           company_link           type  \
# 0  cafesbelleville.com  LocalBusiness
#
#                                     location  \
# 0  14 Bis Rue Lally-Tollendal Paris 75019 FR
#
#                                                 logo  \
# 0  https://s3-eu-west-1.amazonaws.com/tpd/screens...
#
#                           url           phone review_count stars_average  \
# 0  http://cafesbelleville.com  01 42 85 79 37          822           4.9
#
#                        mail
# 0  info@cafesbelleville.com
#                date_published  \
# 0   2021-03-17T14:42:34+00:00
# 1   2021-03-16T09:34:57+00:00
# 2   2021-03-15T14:35:30+00:00
# 3   2021-03-13T20:30:30+00:00
# 4   2021-03-13T13:24:14+00:00
# ..                        ...
# 95  2020-12-26T11:43:27+00:00
# 96  2020-12-25T20:24:03+00:00
# 97  2020-12-25T16:35:12+00:00
# 98  2020-12-24T14:58:39+00:00
# 99  2020-12-23T17:50:07+00:00
#
#                                          title_review  \
# ...
